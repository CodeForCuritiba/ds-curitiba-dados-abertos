# %%
from app import get_downloaded_base156

import pandas as pd

csv_file, csv_encoding = get_downloaded_base156()
# Out:
# Fetching latest base of 156...
# Latest csv url: http://dadosabertos.c3sl.ufpr.br/curitiba/156/2019-09-01_156_-_Base_de_Dados.csv
# Downloading File...
# File Already exists!
# No download needed.
# File source_data/base156.csv; Encoding: ISO-8859-1

# %%
field_names = ['SOLICITACAO', 'TIPO', 'ORGAO', 'DATA',
               'HORARIO', 'ASSUNTO', 'SUBDIVISAO', 'DESCRICAO',
               'LOGRADOURO_ASS', 'BAIRRO_ASS', 'REGIONAL_ASS',
               'MEIO_RESPOSTA', 'OBSERVACAO', 'SEXO', 'BAIRRO_CIDADAO',
               'REGIONAL_CIDADAO', 'DATA_NASC', 'TIPO_CIDADAO',
               'ORGAO_RESP', 'RESPOSTA_FINAL', 'RESPOSTA_FINAL_DETALHE']

data = pd.read_csv(csv_file, sep=';', encoding=csv_encoding, error_bad_lines=False, skiprows=[0,1], 
                   names=field_names)

# %%
data
# Out:
#        SOLICITACAO         TIPO                               ORGAO  \
# 0        7951839.0  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 1        7952208.0   RECLAMAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 2        7953535.0   RECLAMAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 3        7957219.0  SOLICITAÇÃO       SECRETARIA MUNICIPAL DA SAÚDE
# 4        7957475.0  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# ...            ...          ...                                 ...
# 26247    7994887.0  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 26248    7994898.0  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 26249    7994899.0  SOLICITAÇÃO             FUNDAÇÃO DE AÇÃO SOCIAL
# 26250    7994919.0  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
# 26251    7994923.0  SOLICITAÇÃO  INSTITUTO DAS CIDADES INTELIGENTES
#
#                                  DATA                         HORARIO  \
# 0      01/08/2019                      11:07:50
# 1      01/08/2019                      13:36:49
# 2      02/08/2019                      10:39:37
# 3      05/08/2019                      15:23:18
# 4      05/08/2019                      17:23:26
# ...                               ...                             ...
# 26247  31/08/2019                      22:54:17
# 26248  31/08/2019                      23:22:28
# 26249  31/08/2019                      23:28:24
# 26250  01/09/2019                      00:15:19
# 26251  01/09/2019                      00:21:22
#
#                                          ASSUNTO  \
# 0               ILUMINAÇÃO PÚBLICA - VIA PÚBLICA
# 1             MOTORISTAS, COBRADORES E PORTEIROS
# 2                       FAROL DO SABER DE ESCOLA
# 3                           UNIDADE DE SAÚDE 24H
# 4               ILUMINAÇÃO PÚBLICA - VIA PÚBLICA
# ...                                          ...
# 26247                    ABORDAGEM SOCIAL DE RUA
# 26248                    ABORDAGEM SOCIAL DE RUA
# 26249  ATENDIMENTO SOCIAL EM DOMICÍLIO - CRIANÇA
# 26250                    ABORDAGEM SOCIAL DE RUA
# 26251                    ABORDAGEM SOCIAL DE RUA
#
#                                               SUBDIVISAO  \
# 0      IMPLANTAÇÃO DE EXTENSÃO/AMPLIAÇÃO DE REDE EM V...
# 1             RECUSAR PASSAGEIROS SEM MOTIVO JUSTIFICADO
# 2                               HORÁRIO DE FUNCIONAMENTO
# 3               RECURSOS MATERIAIS - MATERIAL PERMANENTE
# 4              MANUTENÇÃO DE LUMINÁRIAS EM VIAS PÚBLICAS
# ...                                                  ...
# 26247               PESSOAS/FAMÍLIAS EM DESABRIGO NA RUA
# 26248               PESSOAS/FAMÍLIAS EM DESABRIGO NA RUA
# 26249                                        NEGLIGÊNCIA
# 26250               PESSOAS/FAMÍLIAS EM DESABRIGO NA RUA
# 26251               PESSOAS/FAMÍLIAS EM DESABRIGO NA RUA
#
#                                                DESCRICAO  \
# 0      SOLICITA A MANUTENÇÃO DE LUMINÁRIA. SEGUE DESC...
# 1      RECLAMA DO MOTORISTA POR RECUSAR PASSAGEIRO, N...
# 2      RECLAMA DO FAROL DO SABER E INOVAÇÃO DONA POMP...
# 3      RECEBEMOS A MANIFESTAÇÃO POR MEIO DO EMAIL DA ...
# 4      SOLICITA A MANUTENÇÃO DE LUMINÁRIA. SEGUE DESC...
# ...                                                  ...
# 26247  SOLICITA ABORDAGEM PARA PESSOA MORANDO EM VIA ...
# 26248  SOLICITA ABORDAGEM PARA SI MESMO, ESTÁ DE BLUS...
# 26249                                           Sigiloso
# 26250  SOLICITA ABORDAGEM PARA UM MORADOR DE RUA QUE ...
# 26251  SOLICITA ABORDAGEM PARA SI MESMO. ESTÁ NA FREN...
#
#                                  LOGRADOURO_ASS         BAIRRO_ASS  ...  \
# 0                      EVELAZIO AUGUSTO BLEY, 0          TATUQUARA  ...
# 1                   BR CENTO E DEZESSEIS, 21315              ATUBA  ...
# 2      ERNESTO GERMANO FRANCISCO HANNEMANN, 592          TATUQUARA  ...
# 3        JORNALISTA EMÍLIO ZOLA FLORENZANO, 835          TATUQUARA  ...
# 4                  PRESIDENTE JOAO GOULART, 585          TATUQUARA  ...
# ...                                         ...                ...  ...
# 26247           PRESIDENTE CARLOS CAVALCANTI, 0             CENTRO  ...
# 26248           PRESIDENTE AFFONSO CAMARGO, 330    JARDIM BOTANICO  ...
# 26249                                  Sigiloso  CIDADE INDUSTRIAL  ...
# 26250                        DOUTOR MURICY, 315             CENTRO  ...
# 26251                        LEON NICOLAS, 2081         CAPAO RASO  ...
#
#       MEIO_RESPOSTA                                         OBSERVACAO SEXO  \
# 0             EMAIL  NÃO INFORMADO PLACA DE IDENTIFICAÇÃO DO POSTE....    M
# 1             EMAIL                 TRANSVERSAL INFORMADA: JOÃO CHEDE.    M
# 2             EMAIL                  NÃO INFORMOU NOME DE FUNCIONÁRIO.    M
# 3             EMAIL                                                NaN    M
# 4             EMAIL           NÃO INFORMOU IDENTIFICAÇÃO DA LUMINÁRIA.    M
# ...             ...                                                ...  ...
# 26247        NENHUM  INFORMA QUE ESTÁ PRÓXIMO A GUARDA MUNICIPAL. T...    M
# 26248        NENHUM                                                NaN    M
# 26249        NENHUM                                                NaN    M
# 26250        NENHUM                                                NaN    F
# 26251        NENHUM                                                NaN    M
#
#       BAIRRO_CIDADAO              REGIONAL_CIDADAO  \
# 0          TATUQUARA    Unidade Regional Tatuquara
# 1          TATUQUARA    Unidade Regional Tatuquara
# 2          TATUQUARA    Unidade Regional Tatuquara
# 3          TATUQUARA    Unidade Regional Tatuquara
# 4          TATUQUARA    Unidade Regional Tatuquara
# ...              ...                           ...
# 26247            NaN                           NaN
# 26248            NaN                           NaN
# 26249     CAPAO RASO  UNIDADE REGIONAL PINHEIRINHO
# 26250         CENTRO       UNIDADE REGIONAL MATRIZ
# 26251            NaN                           NaN
#
#                             DATA_NASC TIPO_CIDADAO  \
# 0      18/10/1969                          CIDADÃO
# 1      18/10/1969                          CIDADÃO
# 2      18/10/1969                          CIDADÃO
# 3      18/10/1969                          CIDADÃO
# 4      18/10/1969                          CIDADÃO
# ...                               ...          ...
# 26247  10/05/1959                          CIDADÃO
# 26248  31/08/2019                          CIDADÃO
# 26249                                      CIDADÃO
# 26250  01/09/2019                          CIDADÃO
# 26251                                      CIDADÃO
#
#                                    ORGAO_RESP  \
# 0      SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS
# 1                     URBANIZAÇÃO DE CURITIBA
# 2            SECRETARIA MUNICIPAL DA EDUCAÇÃO
# 3               SECRETARIA MUNICIPAL DA SAÚDE
# 4      SECRETARIA MUNICIPAL DE OBRAS PÚBLICAS
# ...                                       ...
# 26247                 FUNDAÇÃO DE AÇÃO SOCIAL
# 26248                 FUNDAÇÃO DE AÇÃO SOCIAL
# 26249                 FUNDAÇÃO DE AÇÃO SOCIAL
# 26250                 FUNDAÇÃO DE AÇÃO SOCIAL
# 26251                 FUNDAÇÃO DE AÇÃO SOCIAL
#
#                               RESPOSTA_FINAL  \
# 0                     Conclusão - Automática
# 1                     Conclusão - Automática
# 2                Envio do e-mail de resposta
# 3                     Conclusão - Automática
# 4                     Conclusão - Automática
# ...                                      ...
# 26247  Conclusão - Meio de resposta "Nenhum"
# 26248  Conclusão - Meio de resposta "Nenhum"
# 26249                   Protocolo Consultado
# 26250           Responder para o solicitante
# 26251           Responder para o solicitante
#
#                                   RESPOSTA_FINAL_DETALHE
# 0      SOLICITAÇÃO INCONSISTENTE.  O LOCAL SÓ TEM POS...
# 1      Informamos que encaminhamos a reclamação à emp...
# 2      Sr. Célio,O Farol do Saber Dona Pompília abriu...
# 3      CONFORME RESPONDI ANTERIORMENTE, SOLICITAMOS M...
# 4                                   SOLICITACAO ATENDIDA
# ...                                                  ...
# 26247  Abordagem realizada. Uma pessoa foi encaminhad...
# 26248  EM ABORDAGEM REALIZADA, NÃO FOI ENCONTRADA A P...
# 26249  11 - INFORMAÇÃO AO CONSELHO TUTELAR DA ÁREA DE...
# 26250  EM ABORDAGEM REALIZADA, NÃO FOI ENCONTRADA A P...
# 26251  EM ABORDAGEM REALIZADA, NÃO FOI ENCONTRADA A P...
#
# [26252 rows x 21 columns]

# %%
data[['ORGAO']].groupby(['ORGAO']).size().reset_index(name='counts')
# Out:
#                                 ORGAO  counts
# 0             FUNDAÇÃO DE AÇÃO SOCIAL     136
# 1  INSTITUTO DAS CIDADES INTELIGENTES   21086
# 2     SECRETARIA DO GOVERNO MUNICIPAL     115
# 3       SECRETARIA MUNICIPAL DA SAÚDE     213
# 4                         SISTEMA GTL       1
# 5             URBANIZAÇÃO DE CURITIBA       7
